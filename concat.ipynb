# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

import os

# %%
def get_file_names(path_to_files):
    """
    
    """
    result = []
    for _, path in path_to_files.items():
        try:
            files = os.listdir('data/{}'.format(path))
            tickers = [file.strip('.csv') for file in files]
            result.append(tickers)
        except:
            continue
    return result

# %%
def list_intersection(file_names):
    """
    
    """
    max_length = 0
    max_idx = 0
    for idx in range(len(file_names)):
        cur_len = len(file_names[idx])
        if cur_len > max_length:
            max_idx = idx
            max_length = cur_len
    
    s = set(file_names[max_idx])
    return list(s.intersection(*file_names))

# %%
def get_feature_names(path_to_files, common_element):
    """
    
    """
    features = []
    for _, path in path_to_files.items():
        cols = pd.read_csv('data/{0}/{1}.csv'.format(path, common_element))
        features.append(cols.columns.values)
    return features

# %%
def create_base_df(path_to_files, tickers):
    """
    
    """
    df = pd.read_csv('{0}{1}.csv'.format(path_to_files, tickers[0]))
    df['ticker'] = tickers[0]
    if len(tickers) == 1:
        return df
    
    idx = len(tickers)
    for ticker in tickers[1:]:
        try:
            current_df = pd.read_csv('{0}{1}.csv'.format(path_to_files,
                                                         ticker))
            current_df['ticker'] = ticker
            df = pd.concat([df, current_df], ignore_index=True)
        except:
            print(ticker + ' not found!') 
            
    df.reset_index(drop=True)
    df['Release Date'] = pd.to_datetime(df['Release Date'], format='%b %d, %Y')
    df['Period End'] = pd.to_datetime(df['Period End'])
    return df

# %%
def add_fundamentals(df, tickers, path_to_files, groups):
    """

    """
    # add columns we want to use
    new_groups = []
    for group_num in range(len(groups)):
        new_groups.append(groups[group_num][1:-1])
        all_zeros = np.zeros(len(new_groups[-1]))
        match_group_val = dict(zip(new_groups[-1], all_zeros))
        df = df.assign(**match_group_val)

    group_num = 0
    for group_name, path in path_to_files.items():
        features = new_groups[group_num]
        for ticker in tickers:
            indexes = df[df['ticker']==ticker].index.values
            calendar = df[df['ticker']==ticker]['Period End']
            data = pd.read_csv('data/{0}/{1}.csv'.format(path, ticker))
            data['date'] = pd.to_datetime(data['date'], format='%Y-%m-%d')
            for idx in indexes:
                cond_df = data[(data['date'].dt.year==calendar[idx].year)\
                             & (data['date'].dt.month==calendar[idx].month)]
                if not cond_df.empty:
                    df.loc[idx,features] = cond_df.loc[:,features].values[0]
            print(group_name + ' data for ' + ticker + ' added!')
        print('\n' + group_name + ' features have been added!\n')
        group_num += 1
    return df

# %%
def assign_values(df, n_before, k_after, idx = None, 
                  vals = None, total_inds = None):
    """
    
    """   
    if idx is None:
        prev_days = [str(n) + 'd_before' for n in range(n_before, 0, -1)]
        next_days = [str(k) + 'd_after' for k in range(1, k_after + 1)]
        all_days = prev_days + ['0d_release'] + next_days
        
        quote_inds = ['open', 'high', 'low', 'close', 'volume']
        total_inds = []
        for day in all_days:
            for ind in quote_inds:
                total_inds.append(day + '_' + ind)
        
        init_vals = np.zeros(len(total_inds))
        match_ind_val = dict(zip(total_inds, init_vals))
        df = df.assign(**match_ind_val)        
        return (df, total_inds)
    
    df.loc[idx, total_inds] = vals
    return df,_

# %%
def find_quotes(ticker, quotes, release_day, n_days_before, k_days_after):
    """
    """
    first_date = quotes['date'][0]
    last_date = quotes['date'][len(quotes) - 1]
    
    idx_release_df = quotes[quotes['date'] == release_day]
    if idx_release_df.empty:
        out_shape = (n_days_before + k_days_after + 1, quotes.shape[1] - 1)
        return np.zeros(out_shape)

    idx_release_day = idx_release_df.index[0]
    start_date = max(idx_release_day - n_days_before, 0)
    end_date = min(idx_release_day + k_days_after, len(quotes) - 1)
    
    quotes_needed = quotes.iloc[start_date:end_date + 1, 1:]
    if len(quotes_needed) != n_days_before + k_days_after + 1:
        dif_start = idx_release_day - n_days_before
        dif_end = idx_release_day + k_days_after - len(quotes) + 1
        if dif_start < 0:
            additional_rows = np.zeros((-dif_start, quotes_needed.shape[1]))
            additional_df = pd.DataFrame(additional_rows, 
                                         columns=quotes_needed.columns.values)
            quotes_needed = pd.concat([additional_df, quotes_needed])
        if dif_end > 0:
            additional_rows = np.zeros((dif_end, quotes_needed.shape[1]))
            additional_df = pd.DataFrame(additional_rows, 
                                         columns=quotes_needed.columns.values)
            quotes_needed = pd.concat([quotes_needed, additional_df])
    return quotes_needed.values

# %%
def add_stock_quotes(df, tickers, n_days_before, k_days_after):
    """
    
    """
    df, total_inds = assign_values(df, n_days_before, k_days_after)

    idx = 0
    for ticker in tickers:
        path = 'data/historical_daily_quotes/{}.csv'.format(ticker)
        quotes = pd.read_csv(path)      
        quotes['date'] = pd.to_datetime(quotes['date'], 
                                          format='%Y-%m-%d')
        
        for _, row in df[idx:].iterrows():
            if row['ticker'] != ticker:
                continue    
            release_date = row['Release Date']
            vals = find_quotes(ticker, quotes, release_date, 
                               n_days_before, k_days_after)
            df,_ = assign_values(df, n_days_before, k_days_after, 
                                 idx, vals.flatten(), total_inds)
            idx += 1
        print(ticker + ' stock quotes have been added!')
    return df

# %%
path_to_files = {
    'quotes': 'historical_daily_quotes',
    'estimates': 'estimates',
    'balance': 'fundamentals/balance_sheets',
    'cash': 'fundamentals/cash_flow',
    'enterprise': 'fundamentals/enterprise_value',
    'metrics': 'fundamentals/key_metrics',
    'growth': 'fundamentals/financial_statement_growth'
}

# %%
data = pd.read_csv('data_without_quotes.csv')
data.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1 Release Date  Period End   EPS Forecast  Revenue  \
# 0           0             0   2020-02-20  2019-12-01    --     0.28       --
# 1           1             1   2019-10-25  2019-09-01  0.23     0.32  983.16M
# 2           2             2   2019-07-26  2019-06-01  0.58     0.32  950.72M
# 3           3             3   2019-04-26  2019-03-01  0.35      0.3  942.87M
# 4           4             4   2019-02-08  2018-12-01  0.17     0.35  923.26M
#
#   Forecast.1 ticker  Cash and cash equivalents  \
# 0    968.66M    VTR                        0.0
# 1    931.93M    VTR                148063000.0
# 2    922.96M    VTR                 81987000.0
# 3     911.1M    VTR                 82514000.0
# 4    909.59M    VTR                 72277000.0
#
#                 ...                Gross Profit Growth  Inventory Growth  \
# 0               ...                             0.0000               0.0
# 1               ...                             0.0262               0.0
# 2               ...                            -0.0116               0.0
# 3               ...                            -0.0357               0.0
# 4               ...                            -0.0495               0.0
#
#    Net Income Growth  Operating Cash Flow growth  Operating Income Growth  \
# 0             0.0000                      0.0000                   0.0000
# 1            -0.1639                      0.1531                  -0.0177
# 2             0.2643                     -0.0229                  -0.0005
# 3             0.5982                      0.0912                  -0.0294
# 4            -0.8414                      0.0500                  -0.3965
#
#    R&D Expense Growth  Receivables growth  SG&A Expenses Growth  \
# 0                 0.0                 0.0                0.0000
# 1                 0.0                 0.0                0.0215
# 2                 0.0                 0.0                0.1752
# 3                 0.0                 0.0                0.0965
# 4                 0.0                 0.0                0.1015
#
#    Weighted Average Shares Diluted Growth  Weighted Average Shares Growth
# 0                                  0.0000                          0.0000
# 1                                  0.0183                          0.0457
# 2                                  0.0049                          0.0061
# 3                                  0.0023                          0.0015
# 4                                  0.0001                          0.0012
#
# [5 rows x 124 columns]

# %%
files_in_folders = get_file_names(path_to_files)
common_tickers = list_intersection(files_in_folders)

data = data[data['ticker'].isin(common_tickers)]
data.reset_index(inplace=True, drop=True)
tickers = data['ticker'].unique()

# %%
final_data = add_stock_quotes(data, tickers, 5, 5)
# Out:
# VTR stock quotes have been added!
# WDC stock quotes have been added!
# CMCSA stock quotes have been added!
# AMGN stock quotes have been added!
# C stock quotes have been added!
# RJF stock quotes have been added!
# SPG stock quotes have been added!
# RHI stock quotes have been added!
# L stock quotes have been added!
# FIS stock quotes have been added!
# ARE stock quotes have been added!
# DUK stock quotes have been added!
# QRVO stock quotes have been added!
# MNST stock quotes have been added!
# HSIC stock quotes have been added!
# KIM stock quotes have been added!
# MTB stock quotes have been added!
# KR stock quotes have been added!
# PHM stock quotes have been added!
# CL stock quotes have been added!
# TAP stock quotes have been added!
# MTD stock quotes have been added!
# AEE stock quotes have been added!
# LB stock quotes have been added!
# SWK stock quotes have been added!
# CVX stock quotes have been added!
# KO stock quotes have been added!
# GPS stock quotes have been added!
# MU stock quotes have been added!
# BKNG stock quotes have been added!
# EBAY stock quotes have been added!
# SCHW stock quotes have been added!
# JBHT stock quotes have been added!
# M stock quotes have been added!
# CTSH stock quotes have been added!
# RL stock quotes have been added!
# SJM stock quotes have been added!
# FLIR stock quotes have been added!
# EXR stock quotes have been added!
# F stock quotes have been added!
# AJG stock quotes have been added!
# HLT stock quotes have been added!
# PFG stock quotes have been added!
# ECL stock quotes have been added!
# BMY stock quotes have been added!
# LNC stock quotes have been added!
# VRSK stock quotes have been added!
# CTAS stock quotes have been added!
# CMG stock quotes have been added!
# IP stock quotes have been added!
# AWK stock quotes have been added!
# DD stock quotes have been added!
# AVGO stock quotes have been added!
# DE stock quotes have been added!
# NSC stock quotes have been added!
# GILD stock quotes have been added!
# PYPL stock quotes have been added!
# CTL stock quotes have been added!
# TDG stock quotes have been added!
# NVDA stock quotes have been added!
# BAX stock quotes have been added!
# DISH stock quotes have been added!
# WFC stock quotes have been added!
# TMO stock quotes have been added!
# ZTS stock quotes have been added!
# STZ stock quotes have been added!
# MRK stock quotes have been added!
# PAYX stock quotes have been added!
# UDR stock quotes have been added!
# XEL stock quotes have been added!
# QCOM stock quotes have been added!
# CPRI stock quotes have been added!
# LNT stock quotes have been added!
# COO stock quotes have been added!
# ITW stock quotes have been added!
# CSCO stock quotes have been added!
# AVB stock quotes have been added!
# ALL stock quotes have been added!
# MAS stock quotes have been added!
# MAR stock quotes have been added!
# XOM stock quotes have been added!
# PFE stock quotes have been added!
# BIIB stock quotes have been added!
# APA stock quotes have been added!
# VAR stock quotes have been added!
# MA stock quotes have been added!
# NOC stock quotes have been added!
# NEE stock quotes have been added!
# RE stock quotes have been added!
# GPC stock quotes have been added!
# FB stock quotes have been added!
# KMX stock quotes have been added!
# PEG stock quotes have been added!
# COG stock quotes have been added!
# HUM stock quotes have been added!
# PPL stock quotes have been added!
# OXY stock quotes have been added!
# IPG stock quotes have been added!
# CME stock quotes have been added!
# AFL stock quotes have been added!
# ETR stock quotes have been added!
# BXP stock quotes have been added!
# SYK stock quotes have been added!
# DOV stock quotes have been added!
# PCAR stock quotes have been added!
# ANSS stock quotes have been added!
# NLSN stock quotes have been added!
# ADBE stock quotes have been added!
# MGM stock quotes have been added!
# SPGI stock quotes have been added!
# AIV stock quotes have been added!
# APD stock quotes have been added!
# COTY stock quotes have been added!
# NRG stock quotes have been added!
# EQR stock quotes have been added!
# PG stock quotes have been added!
# TROW stock quotes have been added!
# FMC stock quotes have been added!
# GD stock quotes have been added!
# WEC stock quotes have been added!
# ALXN stock quotes have been added!
# A stock quotes have been added!
# RSG stock quotes have been added!
# PNC stock quotes have been added!
# AME stock quotes have been added!
# FBHS stock quotes have been added!
# DGX stock quotes have been added!
# EQIX stock quotes have been added!
# WMB stock quotes have been added!
# AEP stock quotes have been added!
# EW stock quotes have been added!
# AAL stock quotes have been added!
# PNW stock quotes have been added!
# RTN stock quotes have been added!
# HON stock quotes have been added!
# AMAT stock quotes have been added!
# HD stock quotes have been added!
# STX stock quotes have been added!
# LMT stock quotes have been added!
# CBOE stock quotes have been added!
# PEP stock quotes have been added!
# ADS stock quotes have been added!
# FE stock quotes have been added!
# PGR stock quotes have been added!
# XYL stock quotes have been added!
# NTAP stock quotes have been added!
# FAST stock quotes have been added!
# ILMN stock quotes have been added!
# CTXS stock quotes have been added!
# GM stock quotes have been added!
# VZ stock quotes have been added!
# GOOGL stock quotes have been added!
# NBL stock quotes have been added!
# VLO stock quotes have been added!
# DG stock quotes have been added!
# XRAY stock quotes have been added!
# HBI stock quotes have been added!
# MMM stock quotes have been added!
# AAPL stock quotes have been added!
# COF stock quotes have been added!
# SWKS stock quotes have been added!
# XEC stock quotes have been added!
# SEE stock quotes have been added!
# IRM stock quotes have been added!
# MOS stock quotes have been added!
# SO stock quotes have been added!
# LUV stock quotes have been added!
# UAA stock quotes have been added!
# STT stock quotes have been added!
# ACN stock quotes have been added!
# JPM stock quotes have been added!
# CINF stock quotes have been added!
# ROP stock quotes have been added!
# CAG stock quotes have been added!
# DLTR stock quotes have been added!
# AKAM stock quotes have been added!
# AIG stock quotes have been added!
# AMT stock quotes have been added!
# VMC stock quotes have been added!
# MAA stock quotes have been added!
# CFG stock quotes have been added!
# CLX stock quotes have been added!
# REG stock quotes have been added!
# IVZ stock quotes have been added!
# WMT stock quotes have been added!
# MCHP stock quotes have been added!
# TIF stock quotes have been added!
# SLG stock quotes have been added!
# NOV stock quotes have been added!
# RCL stock quotes have been added!
# CPB stock quotes have been added!
# TGT stock quotes have been added!
# CCL stock quotes have been added!
# GWW stock quotes have been added!
# PVH stock quotes have been added!
# 10640       10688             0   2020-05-05  2020-03-01    --     0.22
# 10641       10689             1   2020-01-29  2019-12-01  0.46     0.44
# 10642       10690             2   2019-10-29  2019-09-01  0.44     0.39
# 10643       10691             3   2019-07-30  2019-06-01  0.45     0.44
# 10644       10692             4   2019-04-30  2019-03-01   0.4     0.39
# 10645       10693             5   2019-01-29  2018-12-01  0.59     0.57
# 10646       10694             6   2018-10-23  2018-09-01  0.51     0.48
# 10647       10695             7   2018-07-25  2018-06-01  0.38     0.36
# 10648       10696             8   2018-04-24  2018-03-01  0.31      0.3
# 10649       10697             9   2018-01-30  2017-12-01  0.49     0.47
# 10650       10698            10   2017-10-24  2017-09-01  0.43     0.41
# 10651       10699            11   2017-07-26  2017-06-01  0.42      0.4
# 10652       10700            12   2017-04-25  2017-03-01  0.39     0.35
# 10653       10701            13   2017-01-24  2016-12-01  0.39     0.44
# 10654       10702            14   2016-10-25  2016-09-01  0.42     0.38
# 10655       10703            15   2016-07-27  2016-06-01  0.37     0.32
# 10656       10704            16   2016-04-26  2016-03-01  0.28     0.28
# 10657       10705            17   2016-01-26  2015-12-01  0.34     0.32
# 10658       10706            18   2015-10-27  2015-09-01  0.34     0.34
# 10659       10707            19   2015-07-28  2015-06-01  0.38     0.37
# 10660       10708            20   2015-04-28  2015-03-01  0.38     0.34
# 10661       10709            21   2015-01-27  2014-12-01  0.35     0.38
# 10662       10710            22   2014-10-28  2014-09-01   0.4     0.37
#
#        Revenue Forecast.1 ticker  Cash and cash equivalents       ...         \
# 0           --    968.66M    VTR               0.000000e+00       ...
# 1      983.16M    931.93M    VTR               1.480630e+08       ...
# 2      950.72M    922.96M    VTR               8.198700e+07       ...
# 3      942.87M     911.1M    VTR               8.251400e+07       ...
# 4      923.26M    909.59M    VTR               7.227700e+07       ...
# 5      936.54M    908.79M    VTR               8.610700e+07       ...
# 6       942.3M    906.16M    VTR               9.368400e+07       ...
# 7      943.71M    861.73M    VTR               9.254300e+07       ...
# 8       895.3M    875.65M    VTR               8.135500e+07       ...
# 9       899.9M    882.25M    VTR               8.510000e+07       ...
# 10      895.5M    884.23M    VTR               1.033530e+08       ...
# 11      883.4M    868.40M    VTR               9.128400e+07       ...
# 12      875.7M    865.03M    VTR               2.867070e+08       ...
# 13      867.1M    843.17M    VTR               8.927900e+07       ...
# 14      848.4M    848.01M    VTR               5.732200e+07       ...
# 15      852.3M    833.89M    VTR               5.170100e+07       ...
# 16      841.3M    810.05M    VTR               5.302300e+07       ...
# 17      827.6M    848.53M    VTR               6.523100e+07       ...
# 18       1.62B    871.21M    VTR               6.053200e+07       ...
# 19      884.0M    855.06M    VTR               1.202250e+08       ...
# 20      804.0M    792.81M    VTR               5.534800e+07       ...
# 21      779.0M    748.99M    VTR               6.459500e+07       ...
# 22      751.2M    741.08M    VTR               8.663500e+07       ...
# 23          --    725.56M    VTR               5.979100e+07       ...
# 24          --      4.06B    WDC               0.000000e+00       ...
# 25       4.23B     4,257M    WDC               0.000000e+00       ...
# 26       4.04B      3.93B    WDC               0.000000e+00       ...
# 27       3.63B      3.66B    WDC               3.455000e+09       ...
# 28       3.67B      3.68B    WDC               3.682000e+09       ...
# 29       4.23B      4.25B    WDC               4.013000e+09       ...
# ...        ...        ...    ...                        ...       ...
# 10633    3.11B     3,001M    AMP               2.357000e+09       ...
# 10634    2.89B     3,064M    AMP               2.780000e+09       ...
# 10635    3.14B     3,109M    AMP               2.570000e+09       ...
# 10636    3.06B     3,104M    AMP               2.809000e+09       ...
# 10637    3.10B     3,057M    AMP               2.638000e+09       ...
# 10638    3.12B     3,064M    AMP               2.876000e+09       ...
# 10639    3.08B     3,029M    AMP               2.141000e+09       ...
# 10640       --      2.58B    GLW               0.000000e+00       ...
# 10641    2.85B       2.7B    GLW               0.000000e+00       ...
# 10642    2.97B      2.88B    GLW               9.710000e+08       ...
# 10643    2.99B      2.98B    GLW               1.178000e+09       ...
# 10644    2.81B      2.83B    GLW               1.456000e+09       ...
# 10645    3.08B      3.01B    GLW               2.355000e+09       ...
# 10646    3.05B      2.99B    GLW               1.903000e+09       ...
# 10647    2.76B      2.67B    GLW               2.023000e+09       ...
# 10648    2.51B      2.49B    GLW               3.096000e+09       ...
# 10649    2.64B     2,650M    GLW               4.317000e+09       ...
# 10650    2.61B     2,598M    GLW               3.865000e+09       ...
# 10651    2.50B     2,536M    GLW               4.189000e+09       ...
# 10652    2.38B     2,370M    GLW               4.844000e+09       ...
# 10653    2.48B     2,499M    GLW               5.291000e+09       ...
# 10654    2.51B     2,518M    GLW               4.821000e+09       ...
# 10655    2.36B     2,384M    GLW               7.144000e+09       ...
# 10656    2.05B     2,234M    GLW               3.540000e+09       ...
# 10657    2.23B     2,331M    GLW               4.500000e+09       ...
# 10658    2.27B     2,505M    GLW               4.440000e+09       ...
# 10659    2.34B     2,540M    GLW               4.968000e+09       ...
# 10660    2.27B     2,480M    GLW               4.304000e+09       ...
# 10661    2.40B     2,496M    GLW               5.309000e+09       ...
# 10662    2.54B     2,630M    GLW               5.353000e+09       ...
#
#        4d_after_open  4d_after_high  4d_after_low  4d_after_close  \
# 0               0.00         0.0000         0.000            0.00
# 1              65.21        65.7100        64.630           65.10
# 2              67.33        67.9500        66.510           67.67
# 3              61.23        61.9900        60.960           61.53
# 4              64.29        64.9236        64.020           64.74
# 5              58.17        58.6100        57.510           58.11
# 6              56.68        57.1900        56.420           56.49
# 7              52.12        52.6000        51.820           52.53
# 8              49.62        50.7500        49.620           50.64
# 9              63.24        64.1800        63.170           63.84
# 10             66.04        66.6900        65.750           66.45
# 11             62.50        62.7350        61.490           62.65
# 12             61.97        63.0000        61.830           62.57
# 13             63.24        63.2400        61.540           61.84
# 14             73.80        73.8800        73.421           73.78
# 15             65.28        65.8600        65.050           65.86
# 16             51.43        52.6800        50.920           52.19
# 17             54.66        54.9900        54.090           54.88
# 18             66.57        66.8800        66.050           66.36
# 19             70.50        70.5600        68.530           68.90
# 20             76.27        77.8000        76.230           77.43
# 21             68.71        68.7100        67.860           68.35
# 22             65.06        65.3900        64.760           64.93
# 23             65.99        66.6500        65.730           66.64
# 24              0.00         0.0000         0.000            0.00
# 25             69.44        70.4800        67.410           68.11
# 26             55.02        55.1800        53.880           54.14
# 27             53.62        54.5000        52.510           53.58
